# %%
import util
from torchvision.datasets import DatasetFolder as DatasetFolder
from tqdm.notebook import tqdm
import multiprocessing

import numpy as np
import pandas as pd

import os
from pathlib import Path

# %%
# DATA_PATH = 'D:\\forecasting'
DATA_PATH = 'E:\\data\\rainfall'

# %%
def file_loader(path):
    return np.load(path)

# %%
dataset_folder = DatasetFolder(DATA_PATH, file_loader, extensions='.npy')
s = next(iter(dataset_folder))[0]

# %%
a = pd.DataFrame(s.reshape(-1, 15))

# %%
a.describe()
# Out:
#                 0            1            2            3            4   \
# count  1600.000000  1600.000000  1600.000000  1600.000000  1600.000000
# mean    174.070798    97.671409   198.759610   136.190539   231.522304
# std       0.706129     1.083615     1.794471     2.960052     3.420229
# min     171.380936    94.558495   193.352509   128.438492   220.612549
# 25%     173.600891    97.018217   197.702076   134.297462   229.940758
# 50%     174.101959    97.733448   198.848625   136.186432   231.854111
# 75%     174.551777    98.394184   199.992382   138.400921   233.663612
# max     176.350510   100.436172   204.429550   147.359085   241.584793
#
#                 5            6            7            8       9   \
# count  1600.000000  1600.000000  1600.000000  1600.000000  1600.0
# mean    218.279989   163.004554   270.526538   248.211535     0.0
# std       1.876561     3.398671     2.489263     5.183757     0.0
# min     212.951294   154.444763   262.195129   231.881042     0.0
# 25%     217.247845   160.830719   269.234009   245.352684     0.0
# 50%     218.270973   162.818680   270.710587   248.423569     0.0
# 75%     219.488972   165.478188   272.133331   251.873512     0.0
# max     230.050507   184.238693   281.690247   274.505585     0.0
#
#                 10           11           12           13           14
# count  1600.000000  1600.000000  1600.000000  1600.000000  1600.000000
# mean    161.223385     7.304808   161.232094     7.301349     0.000138
# std       0.741888     1.301351     0.733260     1.299685     0.005515
# min     159.494385     4.793731   159.625137     4.796376     0.000000
# 25%     160.682163     6.201639   160.696388     6.196418     0.000000
# 50%     161.220520     7.306147   161.223427     7.302068     0.000000
# 75%     161.747314     8.409525   161.749050     8.405701     0.000000
# max     163.031097     9.955291   163.033722     9.874516     0.220583

# %%
util.display_imgs(s.transpose(2,0,1)[:14,:,:], cols=5, figsize=(10, 5))

# %%
round(2.6)
# Out:
# 3
